# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 2*
#
# # Sprint Challenge - Neural Network Foundations
#
# Table of Problems
#
# 1. [Defining Neural Networks](#Q1)
# 2. [Chocolate Gummy Bears](#Q2)
#     - Perceptron
#     - Multilayer Perceptron
# 4. [Keras MMP](#Q3)

# %% [markdown]
# <a id="Q1"></a>
# ## 1. Define the following terms:
#
# - **Neuron:** An individual node in a neural network.
# - **Input Layer:** The layer that receives input data (must be same size as the input data's columns/lists)
# - **Hidden Layer:** The layer that performs the computations based on weights.
# - **Output Layer:** The layer that returns a value/prediction based on the hidden layer and its own weights
# - **Activation:** Applying the weights of a neuron to a mathematical function (like a sigmoid function)
# - **Backpropagation:** Re-balancing weights after an output has been found, and then re-running the network to find a better output

# %% [markdown]
# ## 2. Chocolate Gummy Bears <a id="Q2"></a>
#
# Right now, you're probably thinking, "yuck, who the hell would eat that?". Great question. Your candy company wants to know too. And you thought I was kidding about the [Chocolate Gummy Bears](https://nuts.com/chocolatessweets/gummies/gummy-bears/milk-gummy-bears.html?utm_source=google&utm_medium=cpc&adpos=1o1&gclid=Cj0KCQjwrfvsBRD7ARIsAKuDvMOZrysDku3jGuWaDqf9TrV3x5JLXt1eqnVhN0KM6fMcbA1nod3h8AwaAvWwEALw_wcB).
#
# Let's assume that a candy company has gone out and collected information on the types of Halloween candy kids ate. Our candy company wants to predict the eating behavior of witches, warlocks, and ghosts -- aka costumed kids. They shared a sample dataset with us. Each row represents a piece of candy that a costumed child was presented with during "trick" or "treat". We know if the candy was `chocolate` (or not chocolate) or `gummy` (or not gummy). Your goal is to predict if the costumed kid `ate` the piece of candy.
#
# If both chocolate and gummy equal one, you've got a chocolate gummy bear on your hands!?!?!
# ![Chocolate Gummy Bear](https://ed910ae2d60f0d25bcb8-80550f96b5feb12604f4f720bfefb46d.ssl.cf1.rackcdn.com/3fb630c04435b7b5-2leZuM7_-zoom.jpg)

# %%
import pandas as pd
candy = pd.read_csv('chocolate_gummy_bears.csv')

# %%
print(candy.shape)
candy.head()
# Out:
# (10000, 3)
#    chocolate  gummy  ate
# 0          0      1    1
# 1          1      0    1
# 2          0      1    1
# 3          0      0    0
# 4          1      1    0

# %% [markdown]
# ### Perceptron
#
# To make predictions on the `candy` dataframe. Build and train a Perceptron using numpy. Your target column is `ate` and your features: `chocolate` and `gummy`. Do not do any feature engineering. :P
#
# Once you've trained your model, report your accuracy. You will not be able to achieve more than ~50% with the simple perceptron. Explain why you could not achieve a higher accuracy with the *simple perceptron* architecture, because it's possible to achieve ~95% accuracy on this dataset. Provide your answer in markdown (and *optional* data anlysis code) after your perceptron implementation.

# %%
import numpy as np
# Start your candy perceptron here
class Perceptron(object):
    def __init__(self, rate=0.01, niter=10):
        self.rate = rate
        self.niter = niter
    
    def fit(self, X, y):
        """Fit training data
        X: Training vectors, X.shape : [#Samples, #features]
        y: Target values, y.shape : [#samples]"""
        
        # weights
        self.weight = np.zeros(1 + X.shape[1])
        # no. of misclassificaiton
        self.errors = [] # Number of misclassifications
        for i in range(self.niter):
            error = 0
            for xi, target in zip(X, y):
                predicted = self.predict(xi)
                delta_w = self.rate * (target - predicted)
                self.weight[1:] += delta_w * xi
                self.weight[0] += delta_w
                if delta_w != 0.0:
                    error += 1
            self.errors.append(error)
        return self
    
    def net_input(self, X):
            """Calculate net input"""
            return np.dot(X, self.weight[1:]) + self.weight[0]
    
    def predict(self, X):
        """Return class label after unit step"""
        return np.where(self.net_input(X) >= 0.0, 1, -1)

X = candy[['chocolate', 'gummy']].values
y = candy['ate'].values

print(X.shape)
print(X[0])
# Out:
# (10000, 2)
# [0 1]

# %%
pn = Perceptron()
fitted = pn.fit(X, y)

# %%
print(f' Accuracy for the 10 iterations are: {[(1 - x/len(X)) for x in fitted.errors]}')
# Out:
#  Accuracy for the 10 iterations are: [0.3722, 0.3732, 0.3729, 0.3732, 0.3729, 0.3732, 0.3729, 0.3732, 0.3729, 0.3732]

# %% [markdown]
# **Why can't a Perceptron achieve higher accuracy?**
# The reason that these errors are going to remain roughly the same is that there is no backpropagation happening. There would be more variance if the weights were randomized, but currently they all start at 0. The model will run once through the dataframe, and then will finish with X number of errors. It can't then go back and retrain/rebalance weights to get a better answer.

# %% [markdown]
# ### Multilayer Perceptron <a id="Q3"></a>
#
# Using the sample candy dataset, implement a Neural Network Multilayer Perceptron class that uses backpropagation to update the network's weights. Your Multilayer Perceptron should be implemented in Numpy.
# Your network must have one hidden layer.
#
# Once you've trained your model, report your accuracy. Explain why your MLP's performance is considerably better than your simple perceptron's on the candy dataset.

# %%
class NeuralNetwork:
    def __init__(self):
        # Set up Architecture of Neural Network
        self.inputs = 2
        self.hiddenNodes = 2
        self.outputNodes = 1

        # Initial Weights
        # 2x3 Matrix Array for the First Layer
        self.weights1 = np.random.rand(self.inputs, self.hiddenNodes)
       
        # 3x1 Matrix Array for Hidden to Output
        self.weights2 = np.random.rand(self.hiddenNodes, self.outputNodes)
        
    def sigmoid(self, s):
        return 1 / (1+np.exp(-s))
    
    def sigmoidPrime(self, x):
        s = self.sigmoid(x)
        return s * (1 - s)
    
    def feed_forward(self, X):
        """
        Calculate the NN inference using feed forward.
        aka "predict"
        """
        
        # Weighted sum of inputs => hidden layer
        self.hidden_sum = np.dot(X, self.weights1)
        
        # Activations of weighted sum
        self.activated_hidden = self.sigmoid(self.hidden_sum)
        
        # Weight sum between hidden and output
        self.output_sum = np.dot(self.activated_hidden, self.weights2)
        
        # Final activation of output
        self.activated_output = self.sigmoid(self.output_sum)
        
        return self.activated_output
        
    def backward(self, X,y,o):
        """
        Backward propagate through the network
        """
        
        # Error in Output
        self.o_error = y - o
        
        # Apply Derivative of Sigmoid to error
        # How far off are we in relation to the Sigmoid f(x) of the output
        # ^- aka hidden => output
        self.o_delta = self.o_error * self.sigmoidPrime(o)
        
        # z2 error
        self.z2_error = self.o_delta.dot(self.weights2.T)
        
        # How much of that "far off" can explained by the input => hidden
        self.z2_delta = self.z2_error * self.sigmoidPrime(self.activated_hidden)
        
        # Adjustment to first set of weights (input => hidden)
        self.weights1 += X.T.dot(self.z2_delta)
        # Adjustment to second set of weights (hidden => output)
        self.weights2 += self.activated_hidden.T.dot(self.o_delta)
        

    def train(self, X, y):
        o = self.feed_forward(X)
        self.backward(X,y,o)

# %%
# Didn't need to reshape the X, but the Y did need to become 1 row
y = y.reshape(y.shape[0], 1)

X.shape, y.shape
# Out:
# ((10000, 2), (10000, 1))

# %%
nn = NeuralNetwork()
fitted_nn = nn.train(X, y)

# %%
print(f' Accuracy for the 10 iterations are: {[(1 - x/len(X)) for x in nn.o_error]}')
# Out:
#  Accuracy for the 10 iterations are: [array([0.99996016]), array([0.99995945]), array([0.99996016]), array([1.00005779]), array([1.00006154]), array([0.99996016]), array([1.00005779]), array([1.00006154]), array([1.00005779]), array([1.00005779]), array([0.99996016]), array([1.00006154]), array([1.00005779]), array([0.99996016]), array([0.99996016]), array([1.00005945]), array([0.99995945]), array([0.99996016]), array([1.00006154]), array([0.99996016]), array([0.99996016]), array([0.99996016]), array([1.00006154]), array([1.00006154]), array([0.99995945]), array([0.99995945]), array([1.00005779]), array([1.00005779]), array([1.00005779]), array([1.00005779]), array([0.99995945]), array([0.99996016]), array([1.00006154]), array([0.99995945]), array([0.99995945]), array([0.99996016]), array([0.99996016]), array([1.00006154]), array([1.00005779]), array([0.99995945]), array([0.99995945]), array([1.00005779]), array([1.00006154]), array([0.99996016]), array([0.99995945]), array([1.00006154]), array([1.00005779]), array([0.99996016]), array([1.00005779]), array([1.00005779]), array([1.00006154]), array([1.00005779]), array([0.99996016]), array([0.99995945]), array([1.00005779]), array([0.99995945]), array([1.00006154]), array([1.00005779]), array([0.99996016]), array([1.00006154]), array([1.00006154]), array([1.00005779]), array([1.00006154]), array([1.00006016]), array([1.00006154]), array([0.99995945]), array([0.99995945]), array([0.99995945]), array([1.00005779]), array([0.99995945]), array([0.99996016]), array([0.99995945]), array([1.00005779]), array([0.99995945]), array([0.99995945]), array([0.99995945]), array([1.00006154]), array([0.99996016]), array([0.99995945]), array([1.00006154]), array([1.00006154]), array([1.00006154]), array([0.99995945]), array([1.00006154]), array([1.00006154]), array([1.00006154]), array([0.99996016]), array([0.99995945]), array([1.00005779]), array([0.99996016]), array([0.99996016]), array([0.99996016]), array([0.99995945]), array([0.99996154]), array([1.00006154]), array([1.00006154]), array([0.99995945]), array([1.00005779]), array([0.99995945]), array([0.99995945]), array([1.00005779]), array([1.00005779]), array([0.99996016]), array([1.00005779]), array([0.99995945]), array([1.00006154]), array([1.00006154]), array([1.00005779]), array([0.99995945]), array([1.00006154]), array([0.99996016]), array([1.00006154]), array([0.99995779]), array([0.99995945]), array([1.00006016]), array([0.99995945]), array([1.00005779]), array([1.00005945]), array([0.99995945]), array([0.99995945]), array([0.99995945]), array([0.99996016]), array([0.99996016]), array([1.00005779]), array([0.99996016]), array([1.00005779]), array([0.99996016]), array([1.00006154]), array([1.00005779]), array([1.00006154]), array([0.99996154]), array([0.99995945]), array([1.00005779]), array([1.00005779]), array([0.99996016]), array([1.00006154]), array([1.00006016]), array([0.99996016]), array([0.99995945]), array([0.99995779]), array([0.99996016]), array([0.99996016]), array([0.99995945]), array([1.00006154]), array([1.00005779]), array([1.00006154]), array([1.00006154]), array([1.00006154]), array([1.00005945]), array([1.00005779]), array([1.00006154]), array([1.00005779]), array([0.99995945]), array([1.00006154]), array([0.99996016]), array([1.00006154]), array([1.00005779]), array([0.99996016]), array([0.99996016]), array([0.99996016]), array([1.00005779]), array([1.00005779]), array([0.99995945]), array([1.00005779]), array([1.00006154]), array([0.99996016]), array([0.99995945]), array([0.99995945]), array([0.99995945]), array([1.00006016]), array([0.99995945]), array([1.00006154]), array([0.99995779]), array([1.00005779]), array([0.99995945]), array([1.00006154]), array([1.00006154]), array([1.00005779]), array([0.99996016]), array([0.99995945]), array([1.00006016]), array([0.99996016]), array([0.99996016]), array([0.99995945]), array([1.00006154]), array([1.00006016]), array([1.00006154]), array([0.99995945]), array([1.00005 ...

# %% [markdown]
# P.S. Don't try candy gummy bears. They're disgusting.

# %%
class Neural_Network(object):
    def __init__(self):        
        #Define Hyperparameters
        self.inputLayerSize = 2
        self.outputLayerSize = 1
        self.hiddenLayerSize = 3
        
        #Weights (parameters)
        self.W1 = np.random.randn(self.inputLayerSize,self.hiddenLayerSize)
        self.W2 = np.random.randn(self.hiddenLayerSize,self.outputLayerSize)
        
    def forward(self, X):
        #Propogate inputs though network
        self.z2 = np.dot(X, self.W1)
        self.a2 = self.sigmoid(self.z2)
        self.z3 = np.dot(self.a2, self.W2)
        yHat = self.sigmoid(self.z3) 
        return yHat
        
    def sigmoid(self, z):
        #Apply sigmoid activation function to scalar, vector, or matrix
        return 1/(1+np.exp(-z))
    
    def sigmoidPrime(self,z):
        #Gradient of sigmoid
        return np.exp(-z)/((1+np.exp(-z))**2)
    
    def costFunction(self, X, y):
        #Compute cost for given X,y, use weights already stored in class.
        self.yHat = self.forward(X)
        J = 0.5*sum((y-self.yHat)**2)
        return J
        
    def costFunctionPrime(self, X, y):
        #Compute derivative with respect to W and W2 for a given X and y:
        self.yHat = self.forward(X)
        
        delta3 = np.multiply(-(y-self.yHat), self.sigmoidPrime(self.z3))
        dJdW2 = np.dot(self.a2.T, delta3)
        
        delta2 = np.dot(delta3, self.W2.T)*self.sigmoidPrime(self.z2)
        dJdW1 = np.dot(X.T, delta2)  
        
        return dJdW1, dJdW2
    
    #Helper Functions for interacting with other classes:
    def getParams(self):
        #Get W1 and W2 unrolled into vector:
        params = np.concatenate((self.W1.ravel(), self.W2.ravel()))
        return params
    
    def setParams(self, params):
        #Set W1 and W2 using single paramater vector.
        W1_start = 0
        W1_end = self.hiddenLayerSize * self.inputLayerSize
        self.W1 = np.reshape(params[W1_start:W1_end], (self.inputLayerSize , self.hiddenLayerSize))
        W2_end = W1_end + self.hiddenLayerSize*self.outputLayerSize
        self.W2 = np.reshape(params[W1_end:W2_end], (self.hiddenLayerSize, self.outputLayerSize))
        
    def computeGradients(self, X, y):
        dJdW1, dJdW2 = self.costFunctionPrime(X, y)
        return np.concatenate((dJdW1.ravel(), dJdW2.ravel()))

# %%
from scipy import optimize
class trainer(object):
    def __init__(self, N):
        #Make Local reference to network:
        self.N = N
        
    def callbackF(self, params):
        self.N.setParams(params)
        self.J.append(self.N.costFunction(self.X, self.y))   
        
    def costFunctionWrapper(self, params, X, y):
        self.N.setParams(params)
        cost = self.N.costFunction(X, y)
        grad = self.N.computeGradients(X,y)
        
        return cost, grad
        
    def train(self, X, y):
        #Make an internal variable for the callback function:
        self.X = X
        self.y = y

        #Make empty list to store costs:
        self.J = []
        
        params0 = self.N.getParams()

        options = {'maxiter': 200, 'disp' : True}
        _res = optimize.minimize(self.costFunctionWrapper, params0, jac=True, method='BFGS', \
                                 args=(X, y), options=options, callback=self.callbackF)

        self.N.setParams(_res.x)
        self.optimizationResults = _res

# %%
nn = Neural_Network()
trained_nn = trainer(nn)
trained_nn = trained_nn.train(X, y)
# Out:
# Optimization terminated successfully.
#          Current function value: 256.295819
#          Iterations: 48
#          Function evaluations: 61
#          Gradient evaluations: 61

# %%
print("Predicted Output: \n" + str(nn.forward(X))) 
print("Loss: \n" + str(np.mean(np.square(y - nn.forward(X))))) # mean sum squared loss
# Out:
# Predicted Output:
# [[0.94741068]
#  [0.94777019]
#  [0.94741068]
#  ...
#  [0.94741068]
#  [0.94741068]
#  [0.94777019]]
# Loss:
# 0.05125916383849585

# %% [markdown]
# **Answer:**
# Using both a handmade multi-layer perceptron and the Stochastic GD-based implementation we were shown from Welch Labs, we were able to get very high matching rates for the predicted output, thanks to backpropagation!

# %% [markdown]
# ## 3. Keras MMP <a id="Q3"></a>
#
# Implement a Multilayer Perceptron architecture of your choosing using the Keras library. Train your model and report its baseline accuracy. Then hyperparameter tune at least two parameters and report your model's accuracy.
# Use the Heart Disease Dataset (binary classification)
# Use an appropriate loss function for a binary classification task
# Use an appropriate activation function on the final layer of your network.
# Train your model using verbose output for ease of grading.
# Use GridSearchCV or RandomSearchCV to hyperparameter tune your model. (for at least two hyperparameters)
# When hyperparameter tuning, show you work by adding code cells for each new experiment.
# Report the accuracy for each combination of hyperparameters as you test them so that we can easily see which resulted in the highest accuracy.
# You must hyperparameter tune at least 3 parameters in order to get a 3 on this section.

# %%
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import StandardScaler


df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/heart.csv')
df = df.sample(frac=1)
print(df.shape)
df.head()
# Out:
# (303, 14)
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 237   60    1   0       140   293    0        0      170      0      1.2
# 145   70    1   1       156   245    0        0      143      0      0.0
# 26    59    1   2       150   212    1        1      157      0      1.6
# 293   67    1   2       152   212    0        0      150      0      0.8
# 57    45    1   0       115   260    0        0      185      0      0.0
#
#      slope  ca  thal  target
# 237      1   2     3       0
# 145      2   0     2       1
# 26       2   0     2       1
# 293      1   0     3       0
# 57       2   0     2       1

# %%
np.random.seed(42)
X = df.drop(columns=['target']).values
y = df['target'].values

scaler = StandardScaler()

X = scaler.fit_transform(X)

inputs = X.shape[1]

def make_model():
        model = Sequential()
        model.add(Dense(14, input_shape=(inputs,), activation='relu', ))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(1))
        # Compile model
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

model = KerasClassifier(build_fn=make_model, verbose=1)

fitted = model.fit(X, y, 
          validation_split=0.25, 
          epochs=20, 
          batch_size=5
         )
# Out:
# Train on 227 samples, validate on 76 samples
# Epoch 1/20
# 227/227 [==============================] - 0s 2ms/sample - loss: 2.7409 - accuracy: 0.4670 - val_loss: 0.8635 - val_accuracy: 0.4605
# Epoch 2/20
# 227/227 [==============================] - 0s 369us/sample - loss: 1.1132 - accuracy: 0.4890 - val_loss: 0.7158 - val_accuracy: 0.5263
# Epoch 3/20
# 227/227 [==============================] - 0s 396us/sample - loss: 0.9335 - accuracy: 0.5771 - val_loss: 0.6259 - val_accuracy: 0.5921
# Epoch 4/20
# 227/227 [==============================] - 0s 369us/sample - loss: 0.7949 - accuracy: 0.6564 - val_loss: 0.5603 - val_accuracy: 0.6842
# Epoch 5/20
# 227/227 [==============================] - 0s 369us/sample - loss: 0.7364 - accuracy: 0.7048 - val_loss: 0.5128 - val_accuracy: 0.6974
# Epoch 6/20
# 227/227 [==============================] - 0s 364us/sample - loss: 0.6848 - accuracy: 0.7445 - val_loss: 0.4958 - val_accuracy: 0.7237
# Epoch 7/20
# 227/227 [==============================] - 0s 356us/sample - loss: 0.6456 - accuracy: 0.7665 - val_loss: 0.6197 - val_accuracy: 0.7368
# Epoch 8/20
# 227/227 [==============================] - 0s 411us/sample - loss: 0.6127 - accuracy: 0.7930 - val_loss: 0.5087 - val_accuracy: 0.7368
# Epoch 9/20
# 227/227 [==============================] - 0s 347us/sample - loss: 0.5492 - accuracy: 0.7797 - val_loss: 0.6107 - val_accuracy: 0.7632
# Epoch 10/20
# 227/227 [==============================] - 0s 383us/sample - loss: 0.5046 - accuracy: 0.7885 - val_loss: 0.6272 - val_accuracy: 0.7895
# Epoch 11/20
# 227/227 [==============================] - 0s 378us/sample - loss: 0.4812 - accuracy: 0.8106 - val_loss: 0.7586 - val_accuracy: 0.7895
# Epoch 12/20
# 227/227 [==============================] - 0s 373us/sample - loss: 0.4625 - accuracy: 0.8194 - val_loss: 0.9041 - val_accuracy: 0.8026
# Epoch 13/20
# 227/227 [==============================] - 0s 391us/sample - loss: 0.4520 - accuracy: 0.8326 - val_loss: 0.8910 - val_accuracy: 0.7895
# Epoch 14/20
# 227/227 [==============================] - 0s 382us/sample - loss: 0.4415 - accuracy: 0.8370 - val_loss: 0.8864 - val_accuracy: 0.8026
# Epoch 15/20
# 227/227 [==============================] - 0s 347us/sample - loss: 0.4286 - accuracy: 0.8370 - val_loss: 0.8819 - val_accuracy: 0.8026
# Epoch 16/20
# 227/227 [==============================] - 0s 373us/sample - loss: 0.4209 - accuracy: 0.8546 - val_loss: 0.8740 - val_accuracy: 0.8158
# Epoch 17/20
# 227/227 [==============================] - 0s 359us/sample - loss: 0.4089 - accuracy: 0.8546 - val_loss: 0.8745 - val_accuracy: 0.8158
# Epoch 18/20
# 227/227 [==============================] - 0s 356us/sample - loss: 0.3990 - accuracy: 0.8678 - val_loss: 0.8761 - val_accuracy: 0.8158
# Epoch 19/20
# 227/227 [==============================] - 0s 351us/sample - loss: 0.3939 - accuracy: 0.8634 - val_loss: 0.8785 - val_accuracy: 0.8289
# Epoch 20/20
# 227/227 [==============================] - 0s 360us/sample - loss: 0.3864 - accuracy: 0.8678 - val_loss: 0.8887 - val_accuracy: 0.8158

# %%
# BASELINE MODEL ACCURACY (AFTER 20 EPOCHS, BATCH SIZE=5):
fitted.history['accuracy'][-1]
# Out:
# 0.8678414

# %%
def create_model(optimizer):
        model = Sequential()
        model.add(Dense(14, input_shape=(inputs,), activation='relu', ))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(1))
        # Compile model
        model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
        return model
    
model2 = KerasClassifier(build_fn=create_model, verbose=1)


parameters = {'batch_size': [5, 10, 20, 32],
              'epochs': [10, 20, 35, 50],
              'optimizer': ['SGD','Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
             }

grid = GridSearchCV(estimator=model2, param_grid=parameters, n_jobs = -1)
grid_result = grid.fit(X, y, epochs=30)

print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f"Means: {mean}, Stdev: {stdev} with: {param}")
# Out:
# d:\csfiles\lambda\git\neural_networks\venv\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Train on 303 samples
# Epoch 1/30
# 303/303 [==============================] - 0s 1ms/sample - loss: 0.9402 - accuracy: 0.6304
# Epoch 2/30
# 303/303 [==============================] - 0s 150us/sample - loss: 0.7612 - accuracy: 0.7327
# Epoch 3/30
# 303/303 [==============================] - 0s 122us/sample - loss: 0.6415 - accuracy: 0.7822
# Epoch 4/30
# 303/303 [==============================] - 0s 129us/sample - loss: 0.5604 - accuracy: 0.7987
# Epoch 5/30
# 303/303 [==============================] - 0s 131us/sample - loss: 0.4785 - accuracy: 0.8284
# Epoch 6/30
# 303/303 [==============================] - 0s 128us/sample - loss: 0.4490 - accuracy: 0.8515
# Epoch 7/30
# 303/303 [==============================] - 0s 122us/sample - loss: 0.4297 - accuracy: 0.8548
# Epoch 8/30
# 303/303 [==============================] - 0s 129us/sample - loss: 0.4047 - accuracy: 0.8581
# Epoch 9/30
# 303/303 [==============================] - 0s 129us/sample - loss: 0.3962 - accuracy: 0.8515
# Epoch 10/30
# 303/303 [==============================] - 0s 128us/sample - loss: 0.3666 - accuracy: 0.8680
# Epoch 11/30
# 303/303 [==============================] - 0s 128us/sample - loss: 0.3490 - accuracy: 0.8779
# Epoch 12/30
# 303/303 [==============================] - 0s 135us/sample - loss: 0.3378 - accuracy: 0.8812
# Epoch 13/30
# 303/303 [==============================] - 0s 128us/sample - loss: 0.3294 - accuracy: 0.8812
# Epoch 14/30
# 303/303 [==============================] - 0s 146us/sample - loss: 0.3211 - accuracy: 0.8746
# Epoch 15/30
# 303/303 [==============================] - 0s 139us/sample - loss: 0.3161 - accuracy: 0.8845
# Epoch 16/30
# 303/303 [==============================] - 0s 132us/sample - loss: 0.3083 - accuracy: 0.8812
# Epoch 17/30
# 303/303 [==============================] - 0s 135us/sample - loss: 0.3010 - accuracy: 0.8812
# Epoch 18/30
# 303/303 [==============================] - 0s 142us/sample - loss: 0.2925 - accuracy: 0.8845
# Epoch 19/30
# 303/303 [==============================] - 0s 142us/sample - loss: 0.2856 - accuracy: 0.8878
# Epoch 20/30
# 303/303 [==============================] - 0s 132us/sample - loss: 0.2797 - accuracy: 0.8878
# Epoch 21/30
# 303/303 [==============================] - 0s 155us/sample - loss: 0.2722 - accuracy: 0.8845
# Epoch 22/30
# 303/303 [==============================] - 0s 138us/sample - loss: 0.2669 - accuracy: 0.8812
# Epoch 23/30
# 303/303 [==============================] - 0s 145us/sample - loss: 0.2596 - accuracy: 0.8944
# Epoch 24/30
# 303/303 [==============================] - 0s 142us/sample - loss: 0.2534 - accuracy: 0.9043
# Epoch 25/30
# 303/303 [==============================] - 0s 145us/sample - loss: 0.2537 - accuracy: 0.8977
# Epoch 26/30
# 303/303 [==============================] - 0s 151us/sample - loss: 0.2431 - accuracy: 0.9043
# Epoch 27/30
# 303/303 [==============================] - 0s 148us/sample - loss: 0.2373 - accuracy: 0.9109
# Epoch 28/30
# 303/303 [==============================] - 0s 145us/sample - loss: 0.2329 - accuracy: 0.9109
# Epoch 29/30
# 303/303 [==============================] - 0s 138us/sample - loss: 0.2282 - accuracy: 0.9076
# Epoch 30/30
# 303/303 [==============================] - 0s 142us/sample - loss: 0.2243 - accuracy: 0.9076
# Best: 0.8254098296165466 using {'batch_size': 10, 'epochs': 35, 'optimizer': 'Adam'}
# Means: 0.5548633873462677, Stdev: 0.1594836147356541 with: {'batch_size': 5, 'epochs': 10, 'optimizer': 'SGD'}
# Means: 0.5747540771961213, Stdev: 0.08074583013879362 with: {'batch_size': 5, 'epochs': 10, 'optimizer': 'Adagrad'}
# Means: 0.455409836769104, Stdev: 0.03807233685447295 with: {'batch_size': 5, 'epochs': 10, 'optimizer': 'Adadelta'}
# Means: 0.8086885213851929, Stdev: 0.02604237728903427 with: {'batch_size': 5, 'epochs': 10, 'optimizer': 'Adam'}
# Means: 0.6761202096939087, Stdev: 0.06118305981408235 with: {'batch_size': 5, 'epochs': 10, 'optimizer': 'Adamax'}
# Means: 0.8051912546157837, Stdev: 0.037278822134527885 with: {'batch_size': 5, 'epochs': 10, 'optimizer': 'Nadam'}
# Means: 0.7697267711162568, Stdev: 0.17454465234158612 with: {'batch_size': 5, 'epochs': 20, 'optimizer': 'SGD'}
# Means: 0.5604918003082275, Stdev: 0.10207580303836647 with: {'batch_size': 5, 'epochs': 20, 'optimizer': 'Adagrad'}
# Means: 0.5207650184631347, Stdev: 0.14009067870764708 with: {'batch_size': 5, 'epochs': 20, 'optimizer': 'Adadelta'}
# Means: 0.7920764923095703, Stdev: 0.01983539566784143 with: {'batch_size': 5, 'epochs': 20, 'optimizer': 'Adam'}
# Means: 0.5177595674991607, Stdev: 0.11432211865791019 with: {'batch_size': 5, 'epochs': 20, 'optimizer': 'Adamax'}
# Means: 0.8186885237693786, Stdev: 0.03802022675536632 with: {'batch_size': 5, 'epochs': 20, 'optimizer': 'Nadam'}
# Means: 0.5315300524234772, Stdev: 0.05432188414046137 with: {'batch_size': 5, 'epochs': 35, 'optimizer': 'SGD'}
# Means: 0.5247541010379791, Stdev: 0.10956845332800313 with: {'batch_size': 5, 'epochs': 35, 'optimizer': 'Adagrad'}
# Means: 0.438852459192276, Stdev: 0.04913003046691889 with: {'batch_size': 5, 'epochs': 35, 'optimizer': 'Adadelta'}
# Means: 0.7465027272701263, Stdev: 0.1608747615107107 with: {'batch_size': 5, 'epochs': 35, 'optimizer': 'Adam'}
# Means: 0.590874308347702, Stdev: 0.14534138370294503 with: {'batch_size': 5, 'epochs': 35, 'optimizer': 'Adamax'}
# Means: 0.8150819659233093, Stdev: 0.04246832483067818 with: {'batch_size': 5, 'epochs': 35, 'optimizer': 'Nadam'}
# Means: 0.5843169331550598, Stdev: 0.1934942930185281 with: {'batch_size': 5, 'epochs': 50, 'optimizer': 'SGD'}
# Means: 0.5742076396942138, Stdev: 0.14319761420821192 with: {'batch_size': 5, 'epochs': 50, 'optimizer': 'Adagrad'}
# Means: 0.4488524556159973, Stdev: 0.05171529568947887 with: {'batch_size': 5, 'epochs': 50, 'optimizer': 'Adadelta'}
# Means: 0.8151365995407105, Stdev: 0.035331822379687364 with: {'batch_size': 5, 'epochs': 50, 'optimizer': 'Adam'}
# Means: 0.5715846955776215, Stdev: 0.11550120513446435 with: {'batch_size': 5, 'epochs': 50, 'optimizer': 'Adamax'}
# Means: 0.8187431812286377, Stdev: 0.033294612711998565 with: {'batch_size': 5, 'epochs': 50, 'optimizer': 'Nadam'}
# Means: 0.5537158429622651, Stdev: 0.1483971917827414 with: {'batch_size': 10, 'epochs': 10, 'optimizer': 'SGD'}
# Means: 0.5513661205768585, Stdev: 0.11064339745259585 with: {'batch_size': 10, 'epochs': 10, 'optimizer': 'Adagrad'}
# Means: 0.48475409746170045, Stdev: 0.08128834151022586 with: {'batch_size': 10, 'epochs': 10, 'optimizer': 'Adadelta'}
# Means: 0.7690163850784302, Stdev: 0.04044513268732637 with: {'batch_size': 10, 'epochs': 10, 'optimizer': 'Adam'}
# Means: 0.5913661181926727, Stdev: 0.12390686259819507 with: {'batch_size': 10, 'epochs': 10, 'optimizer': 'Adamax'}
# Means: 0.7921857953071594, Stdev: 0.03345298988382148 with: {'batch_size': 10, 'epochs': 10, 'optimizer': 'Nadam'}
# Means: 0.6534972608089447, Stdev: 0.15852103481232366 with: {'batch_size': 10, 'epochs': 20, 'optimizer': 'SGD'}
# Means: 0.598032784461975, Stdev: 0.1188771914270812 with: {'batch_size': 10, 'epochs': 20, 'optimizer': 'Adagrad'}
# Means: 0.4522404372692108, Stdev: 0.060572343423815046 with: {'batch_size': 10, 'epochs': 20, 'optimizer': 'Adadelta'}
# Means: 0.8054644823074341, Stdev: 0.027136537908409898 with: {'batch_size': 10, 'epochs': 20, 'optimizer': 'Adam'}
# Means: 0.5975409746170044, Stdev: 0.06794088292680772 with: {'batch_size': 10, 'epochs': 20, 'optimizer': 'Adamax'}
# Means: 0.7591803312301636, Stdev: 0.049878957981344264 with: {'batch_size': 10, 'epochs': 20, 'optimizer': 'Nadam'}
# Means: 0.7595628440380097, Stdev: 0.14566598472530387 with: {'batch_size': 10, 'epochs': 35, 'optimizer': 'SGD'}
# Means: 0.5642076373100281, Stdev: 0.04856937443241141 with: {'batch_size': 10, 'epochs': 35, 'optimizer': 'Adagrad'}
# Means: 0.44868852496147155, Stdev: 0.04432109190168156 with: {'batch_size': 10, 'epochs': 35, 'optimizer': 'Adadelta'}
# Means: 0.8254098296165466, Stdev: 0.060375965709399376 with: {'batch_size': 10, 'epochs': 35, 'optimizer': 'Adam'}
# Means: 0.561803275346756, Stdev: 0.10494883237781887 with: {'batch_size': 10, 'epochs': 35, 'optimizer': 'Adamax'}
# Means: 0.726721316576004, Stdev: 0.13386265665854702 with: {'batch_size': 10, 'epochs': 35, 'optimizer': 'Nadam'}
# Means: 0.6205464363098144, Stdev: 0.12420060860150442 with: {'batch_size': 10, 'epochs': 50, 'optimizer': 'SGD'}
# Means: 0.5315846979618073, Stdev: 0.16119001433841618 with: {'batch_size': 10, 'epochs': 50, 'optimizer': 'Adagrad'}
# Means: 0.5353005468845368, Stdev: 0.09713678763611705 with: {'batch_size': 10, 'epochs': 50, 'optimizer': 'Adadelta'}
# Means: 0.7456830501556396, Stdev: 0.05495361969839244 with: {'batch_size': 10, 'epochs': 50, 'optimizer': 'Adam'}
# Means: 0.5743169188499451, Stdev: 0.05619415031676196 with: {'batch_size': 10, 'epochs': 50, 'optimizer': 'Adamax'}
# Means: 0.7201639473438263, Stdev: 0.1527156175712197 with: {'batch_size': 10, 'epochs': 50, 'optimizer': 'Nadam'}
# Means: 0.7855191230773926, Stdev: 0.014010837747812541 with: {'batch_size': 20, 'epochs': 10, 'optimizer': 'SGD'}
# Means: 0.5904371500015259, Stdev: 0.062274949835078794 with: {'batch_size': 20, 'epochs': 10, 'optimizer': 'Adagrad'}
# Means: 0.5087431609630585, Stdev: 0.06679531031456855 with: {'batch_size': 20, 'epochs': 10, 'optimizer': 'Adadelta'}
# Means: 0.808852469921112, Stdev: 0.046174259032560984 with: {'batch_size': 20, 'epochs': 10, 'optimizer': 'Adam'}
# Means: 0.5737158417701721, Stdev: 0.12451420527027365 with: {'batch_size': 20, 'epochs': 10, 'optimizer': 'Adamax'}
# Means: 0.749234962463379, Stdev: 0.040830462343749624 with: {'batch_size': 20, 'epochs': 10, 'optimizer': 'Nadam'}
# Means: 0.709453535079956, Stdev: 0.14723359787021342 with: {'batch_size': 20, 'epochs': 20, 'optimizer': 'SGD'}
# Means: 0.4951366126537323, Stdev: 0.05065912773691649 with: {'batch_size': 20, 'epochs': 20, 'optimizer': 'Adagrad'}
# Means: 0.4454644799232483, Stdev: 0.028167050918814565 with: {'batch_size': 20, 'epochs': 20, 'optimizer': 'Adadelta'}
# Means: 0.6901092946529388, Stdev: 0.11644966928650856 with: {'batch_size': 20, 'epochs': 20, 'optimizer': 'Adam'}
# Means: 0.5314753949642181, Stdev: 0.057349817194088396 with: {'batch_size': 20, 'epochs': 20, 'optimizer': 'Adamax'}
# Means: 0.7001092851161956, Stdev: 0.11719885948254516 with: {'batch_size': 20, 'epochs': 20, 'optimizer': 'Nadam'}
# Means: 0.6338251233100891, Stdev: 0.1507276181436 with: {'batch_size': 20, 'epochs': 35, 'optimizer': 'SGD'}
# Means: 0.48803278207778933, Stdev: 0.09367822164449945 with: {'batch_size': 20, 'epochs': 35, 'optimizer': 'Adagrad'}
# Means: 0.49158469438552854, Stdev: 0.030903759462000052 with: {'batch_size': 20, 'epochs': 35, 'optimizer': 'Adadelta'}
# Means: 0.7821857929229736, Stdev: 0.04259682955576372 with: {'batch_size': 20, 'epochs': 35, 'optimizer': 'Adam'}
# Means: 0.583715844154358, Stdev: 0.10509784129137986 with: {'batch_size': 20, 'epochs': 35, 'optimizer': 'Adamax'}
# Means: 0.8185245990753174, Stdev: 0.029423272609858 with: {'batch_size': 20, 'epochs': 35, 'optimizer': 'Nadam'}
# Means: 0.6730054616928101, Stdev: 0.19988077401045462 with: {'batch_size': 20, 'epochs': 50, 'optimizer': 'SGD'}
# Means: 0.5250273227691651, Stdev: 0.12759412412375726 with: {'batch_size': 20, 'epochs': 50, 'optimizer': 'Adagrad'}
# Means: 0.44868852496147155, Stdev: 0.03917099573550949 with: {'batch_size': 20, 'epochs': 50, 'optimizer': 'Adadelta'}
# Means: 0.7589617371559143, Stdev: 0.02965476846723124 with: {'batch_size': 20, 'epochs': 50, 'optimizer': 'Adam'}
# Means: 0.47169398665428164, Stdev: 0.03509778585237706 with: {'batch_size': 20, 'epochs': 50, 'optimizer': 'Adamax'}
# Means: 0.756393438577652, Stdev: 0.14392924029561463 with: {'batch_size': 20, 'epochs': 50, 'optimizer': 'Nadam'}
# Means: 0.6266120135784149, Stdev: 0.12680251108822685 with: {'batch_size': 32, 'epochs': 10, 'optimizer': 'SGD'}
# Means: 0.5143715739250183, Stdev: 0.07743336647530602 with: {'batch_size': 32, 'epochs': 10, 'optimizer': 'Adagrad'}
# Means: 0.4624043762683868, Stdev: 0.07779119084764874 with: {'batch_size': 32, 'epochs': 10, 'optimizer': 'Adadelta'}
# Means: 0.7427868843078613, Stdev: 0.028758758321302175 with: {'batch_size': 32, 'epochs': 10, 'optimizer': 'Adam'}
# Means: 0.48163933753967286, Stdev: 0.05872356990943993 with: {'batch_size': 32, 'epochs': 10, 'optimizer': 'Adamax'}
# Means: 0.7455737590789795, Stdev: 0.06699427426134177 with: {'batch_size': 32, 'epochs': 10, 'optimizer': 'Nadam'}
# Means: 0.6759562849998474, Stdev: 0.10727096828929948 with: {'batch_size': 32, 'epochs': 20, 'optimizer': 'SGD'}
# Means: 0.5045355141162873, Stdev: 0.08262497976475708 with: {'batch_size': 32, 'epochs': 20, 'optimizer': 'Adagrad'}
# Means: 0.4980874300003052, Stdev: 0.07995079297205183 with: {'batch_size': 32, 'epochs': 20, 'optimizer': 'Adadelta'}
# Means: 0.7688524484634399, Stdev: 0.06423030737425427 with: {'batch_size': 32, 'epochs': 20, 'optimizer': 'Adam'}
# Means: 0.5943715810775757, Stdev: 0.08703282351982454 with: {'batch_size': 32, 'epochs': 20, 'optimizer': 'Adamax'}
# Means: 0.709453547000885, Stdev: 0.06159018786719155 with: {'batch_size': 32, 'epochs': 20, 'optimizer': 'Nadam'}
# Means: 0.7498360574245453, Stdev: 0.1641598235404843 with: {'batch_size': 32, 'epochs': 35, 'optimizer': 'SGD'}
# Means: 0.5407650291919708, Stdev: 0.08267786690675746 with: {'batch_size': 32, 'epochs': 35, 'optimizer': 'Adagrad'}
# Means: 0.4323497235774994, Stdev: 0.05739281258489747 with: {'batch_size': 32, 'epochs': 35, 'optimizer': 'Adadelta'}
# Means: 0.7789617538452148, Stdev: 0.0335342777509611 with: {'batch_size': 32, 'epochs': 35, 'optimizer': 'Adam'}
# Means: 0.5644262194633484, Stdev: 0.1322287339226684 with: {'batch_size': 32, 'epochs': 35, 'optimizer': 'Adamax'}
# Means: 0.7527868866920471, Stdev: 0.04847318987880444 with: {'batch_size': 32, 'epochs': 35, 'optimizer': 'Nadam'}
# Means: 0.6367759525775909, Stdev: 0.17668227531067193 with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'SGD'}
# Means: 0.5318032801151276, Stdev: 0.11607071982890549 with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adagrad'}
# Means: 0.44923496842384336, Stdev: 0.06126713353929999 with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adadelta'}
# Means: 0.8185245990753174, Stdev: 0.022995275712492196 with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adam'}
# Means: 0.5774863362312317, Stdev: 0.0849999215116642 with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax'}
# Means: 0.7656830549240112, Stdev: 0.037915225950748095 with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam'}

# %% [markdown]
# Seems like the best batch size is 10, the best number of epochs was 35, and the best optimizer is Adam, just based on the non-random Gridsearch.
